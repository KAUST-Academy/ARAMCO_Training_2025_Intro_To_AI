# %% [markdown]
# > This notebook is copied from [MEDVATION](https://www.medvation.net/)'s material

# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # **Introduction to Basic Programming Concepts: Understanding the Building Blocks of Coding**
#
# ### Introduction:
#
# This notebook is designed to introduce fundamental programming concepts to beginners in a clear and engaging way. Whether you're just starting your coding journey or looking to strengthen your understanding of core principles, this notebook provides concise definitions, examples, and explanations of key terms used in computer science and programming.
#
# By the end of this notebook, you will:
#
# - Understand essential programming concepts such as variables, loops, and conditionals.
# - Learn how these concepts fit together to solve problems in logical steps.
# - Gain confidence in reading and writing basic code.
#
# This resource serves as a foundation for exploring more advanced programming topics and developing problem-solving skills in a structured manner. Let's dive into the world of programming and learn how to think like a coder!

# %% [markdown]
# # **Table of Content**
#
# 1. Variables
# 2. Comments
# 3. Data Types (e.g., strings, integers)
# 4. Data Structures (lists, dictionaries, etc.)
# 5. Operations (arithmetic, logical, etc.)
# 6. Conditional Statements (if statement)
# 7. Loops (for loop, while loop)
# 8. Functions and Return Statement
# 9. Input/Output (I/O)
# 10. Applied Project

# %% [markdown]
# # 1. Variable:
# * Definition: A variable is a container for storing data. It gives data a name so that it can be reused and manipulated in a program.
#
# ![assign-value-to-variable.png](data:image/png;base64,...)
#
# * Example:

# %%
x = 5  # Here, 'x' is a variable that stores the value 5.

# %% [markdown]
# # 2. Comment:
# * Definition: Notes in the code that explain what it does. Comments are ignored by the computer when the program runs.
# * Example:

# %%
# This is a comment
x = 10  # Assign 10 to variable x

# %%
# @title 🌍 Exercise:
print("Create a variable temperature and assign it a value of 22. Print the value of temperature to the console.")
print("Add a comment explaining what the variable temperature represents")
# Out:
# Create a variable temperature and assign it a value of 22. Print the value of temperature to the console.
# Add a comment explaining what the variable temperature represents

# %% [markdown]
# # 3. Data Types:

# %% [markdown]
# ### 3.1 Integer
# Definition: A whole number that can be positive, negative, or zero. Integers do not have decimals or fractions.

# %%
# Variables store information that can be used later
x = 10  # Integer
print(type(x))

# %% [markdown]
# ### 3.2 Float
# Definition: A number that has a decimal point. Floats can be positive, negative, or zero.

# %%
y = 3.14  # Float
print(type(y))

# %% [markdown]
# ### 3.3 String
# Definition: A sequence of characters enclosed in quotes. Strings are used to store text.

# %%
name = "Adam"  # String
print(type(name))

# %% [markdown]
# ### 3.4 Boolean
# Definition: A value that is either True or False. Booleans are used for logical operations.

# %%
is_active = True  # Boolean
print(type(is_active))

# %%
# @title ☀️Exercise:
print('Create a variable planet_name with the string value "Earth" and print it. \nAlso, create an integer variable distance_from_sun with a value of 149600000 (in kilometers) and print it.')
print('The output should be: "The distance between Earth and the Sun is 149600000" using the 2 variables in one print statement')
# Out:
# Create a variable planet_name with the string value "Earth" and print it.
# Also, create an integer variable distance_from_sun with a value of 149600000 (in kilometers) and print it.
# The output should be: "The distance between Earth and the Sun is 149600000" using the 2 variables in one print statement

# %% [markdown]
# # 4. Data Structure:

# %% [markdown]
# ## 4.1 Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized empty.
# ![elements-in-python-list-1024x495.jpg](data:image/jpeg;base64,...)

# %%
my_list = []

# %% [markdown]
# or with some initial elements

# %%
my_list = [1, 2, 3]

# %% [markdown]
# can be from the same data type or different data type

# %%
my_list = [1, 2, 3] # Integers
my_list = [1, 2, 'three'] # Integers and string

# %% [markdown]
# Lists have many properties and functions. e.x

# %%
list_var = [1, 2, 3, 4]
print("List:", list_var)

# %%
# Lists have a dynamic size
print("Length:", len(list_var))

# %%
# We can access individual elements of a list (indexing starts from 0)
print("Access first element:", list_var[0])

# %%
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:
print("Slice [1:3]:", list_var[1:3])

# %%
# Omitting the second index means that the slice shoud run until the end of the list
print("Slice [1:]:", list_var[1:])

# %%
# We can check if an element is in the list using `in`
print(5 in list_var)

# %%
# elements can be added (appended) to them
list_var.append(5)
print("After appending 5:", list_var)

# %%
# can insert element in specific index
list_var.insert(1, 1.5)
print("After inserting 1.5 at index 1:", list_var)

# %%
# or remove elemnt from a specific index
list_var.remove(2)
print("After removing 2:", list_var)

# %%
# or pop the lst element
popped_element = list_var.pop(0)
print("Popped element:", popped_element)
print("List after popping:", list_var)

# %%
# list can be sorted ascending or descending
list_var.sort()
print("Sorted list ascending:", list_var)
list_var.sort(reverse=True)
print("Sorted list descending:", list_var)

list_var.reverse()
print("Reversed list:", list_var)
# Out:
# List: [1, 2, 3, 4]
# Length: 4
# Access first element: 1
# Slice [1:3]: [2, 3]
# Slice [1:]: [2, 3, 4]
# False
# After appending 5: [1, 2, 3, 4, 5]
# After inserting 1.5 at index 1: [1, 1.5, 2, 3, 4, 5]
# After removing 2: [1, 1.5, 3, 4, 5]
# Popped element: 1
# List after popping: [1.5, 3, 4, 5]
# Sorted list ascending: [1.5, 3, 4, 5]
# Sorted list descending: [5, 4, 3, 1.5]
# Reversed list: [1.5, 3, 4, 5]

# %% [markdown]
# ## 4.2 Tuples
# Definition: A tuple is an ordered, immutable collection of elements, defined with parentheses ().

# %%
# Tuples are like lists, but they are immutable
tuple_var = (1, 2, 3, 'four')

print("Tuple:", tuple_var)
print("Length:", len(tuple_var))
print("Access first element:", tuple_var[0])
print("Slice [1:3]:", tuple_var[1:3])
print("Count of 'four':", tuple_var.count('four'))
print("Index of 2:", tuple_var.index(2))

# %% [markdown]
# ## 4.3 Set
# Definition: A set is an unordered collection of unique elements, defined with curly braces {}, it has no Indexing or Slicing.

# %%
# 1. Unordered
s = {1, 2, 3}
print(s)  # Output: {1, 2, 3} (order may vary)

# 2. Unique Elements
s_unique = {1, 2, 2, 3}
print(s_unique)  # Output: {1, 2, 3} (duplicates are removed)

# 3. Mutable
s_mutable = {1, 2, 3}
s_mutable.add(4)  # You can add elements
print(s_mutable)  # Output: {1, 2, 3, 4}

# 4. Can Store Multiple Data Types
s_mixed = {1, "hello", 3.5}
print(s_mixed)  # Output: {1, 'hello', 3.5}

# %% [markdown]
# ## 3.5 Dictionaries
# Dictionaries store data in key-value pairs. Key-values must be the same data type but the values can be different

# %%
mixed_d_t = {"name": "Hala", "age": 16, "student": True}
str_keys = {'key1': 'value1', 'key2': 'value2'}
int_keys = {1: 'value1', 2: 'value2'}

# %%
# Adding new key-value pairs
person["city"] = "Jeddah"
print(person)

# %%
# Dictionaries store data in key-value pairs
dict_var = {'key1': 'value1', 'key2': 'value2'}
print("Dictionary:", dict_var)
print("Length:", len(dict_var))
# Accessing dictionary elements
print("Access value for 'key1':", dict_var['key1'])
# Get dictionary keys
print("Keys:", dict_var.keys())
# Get dictionary values
print("Values:", dict_var.values())
# Get dictionary items
print("Items:", dict_var.items())
print("Get value for 'key1':", dict_var.get('key1'))
removed_value = dict_var.pop('key1')
print("Removed value for 'key1':", removed_value)
print("Dictionary after removing 'key1':", dict_var)
dict_var.update({'key3': 'value3'})
print("Dictionary after adding key3:", dict_var)
dict_var.clear()
print("Dictionary after clearing:", dict_var)
# Out:
# Dictionary: {'key1': 'value1', 'key2': 'value2'}
# Length: 2
# Access value for 'key1': value1
# Keys: dict_keys(['key1', 'key2'])
# Values: dict_values(['value1', 'value2'])
# Items: dict_items([('key1', 'value1'), ('key2', 'value2')])
# Get value for 'key1': value1
# Removed value for 'key1': value1
# Dictionary after removing 'key1': {'key2': 'value2'}
# Dictionary after adding key3: {'key2': 'value2', 'key3': 'value3'}
# Dictionary after clearing: {}

# %% [markdown]
# ### Summary Table
#
# | Feature/Type    | Strings               | Lists                   | Tuples                 | Dictionaries          |
# |------------------|-----------------------|-------------------------|------------------------|------------------------|
# | Mutability        | Immutable             | Mutable                 | Immutable              | Mutable                |
# | Order             | Ordered               | Ordered                 | Ordered                | Unordered (3.7+ preserves insertion) |
# | Indexing          | Yes                   | Yes                     | Yes                    | No (accessed by keys)  |
# | Iteration         | Yes                   | Yes                     | Yes                    | Yes                    |
# | Example Creation  | `s = "hello"`        | `l = [1, 2, 3]`        | `t = (1, 2, 3)`       | `d = {'key': 'value'}` |
# | Length            | `len(s)`             | `len(l)`                | `len(t)`               | `len(d)`               |
# | Accessing         | `s[0]`                | `l[0]`                  | `t[0]`                 | `d['key']`             |
# | Common Methods    | `s.lower()`          | `l.append(x)`           | `t.count(x)`           | `d.keys()`             |

# %% [markdown]
# ## 3.6 Notes: A string in Python can be treated like a list because it is a sequence of characters.

# %%
str_var = "Hello, World!"
hello = 'Hello, '
world = 'World'
print("String:", str_var)
print("Length:", len(str_var))

#Strings behave similarly to lists. As such we can access individual elements in exactly the same way
print("Access first character:", str_var[0])

# and similarly for slices
print("Slice [0:5]:", str_var[0:5])

# they have many properties and methods
print('Sum of two strings', hello + world)
print("Lowercase:", str_var.lower())
print("Uppercase:", str_var.upper())
print("Split:", str_var.split(","))
print("Replace 'World' with 'Python':", str_var.replace("World", "Python"))
print("Index of 'lo':", str_var.find("lo"))
print("Count of 'o':", str_var.count("o"))

# %%
# @title 🚀Exercise:
print('Create a list of countries that are known for space exploration: USA, Russia, China, ESA, and India. \nAlso, create a dictionary with a key "Country" and a value "USA",another key "Agency" and value "NASA" and print both.')
# Out:
# Create a list of countries that are known for space exploration: USA, Russia, China.
# Also, create a dictionary with a key "Country" and a value "USA",another key "Agency" and value "NASA" and print both.

# %% [markdown]
# # 5. Operations:
# Definition: Actions or processes that manipulate data or perform calculations.

# %% [markdown]
# ## 5.1 Arithmetic operations
#
# Python supports the usual arithmetic operators: + (addition), * (multiplication), / (division), ** (power), // (integer division).

# %%
a = 15
b = 4

print(a + b)  # Addition
print(a - b)  # Subtraction
print(a * b)  # Multiplication
print(a / b)  # Division (float result)
print(a // b)  # Floor division
print(a % b)  # Modulus
print(a ** b)  # Exponentiation

# %% [markdown]
# ## 5.2 Assignment Operators

# %%
# Assignment operators are used to assign values to variables
a = 10  # Basic assignment
print(a)
a += 5  # Equivalent to a = a + 5
print(a)
a -= 3  # Equivalent to a = a - 3
print(a)
a *= 2  # Equivalent to a = a * 2
print(a)
a /= 2  # Equivalent to a = a / 2
print(a)

# %% [markdown]
# ## 5.3 Comparison Operators

# %%
# Comparison operators compare two values and return True or False
x = 10
y = 5

print(x == y)  # Equal
print(x != y)  # Not equal
print(x > y)  # Greater than
print(x < y)  # Less than
print(x >= y)  # Greater than or equal to
print(x <= y)  # Less than or equal to

# %% [markdown]
# ## 5.4 Logical Operators

# %%
# Logical operators combine conditional statements
x = True
y = False

print(x and y)  # True if both are True
print(x or y)  # True if at least one is True
print(not x)  # True if x is False

print(30*'-')
print(x & y)  # True if both are True
print(x | y)  # True if at least one is True
# Out:
# False
# True
# False
# ------------------------------
# False
# True

# %% [markdown]
# ##  5.5 Membership Operators

# %%
# Membership operators check if a sequence is present in an object
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)  # Returns True because "banana" is in the list
print("orange" not in fruits)  # Returns True because "orange" is not in the list

# %%
# @title 🌆Exercise:
print('Calculate the average temperature between two cities, jeddah = 37 and riyadh = 30, and check if the average temperature is above 32.')
# Out:
# Calculate the average temperature between two cities, jeddah = 37 and riyadh = 30, and check if the average temperature is above 32.

# %% [markdown]
# # 6. Conditional Statements(If Statement):
# * Definition: An if statement is used to execute a block of code only if a specified condition is true. It helps make decisions in a program.
#
#
#
# ![if-statement.png](data:image/png;base64,...)
#
# * Example:

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.

# %%
if x > 0:
    print("x is positive")  # This code runs only if x is greater than 0.
# Out:
# x is positive

# %%
is_sunny = True
if is_sunny:
    print("Wear sunglasses!")  # Runs if is_sunny is True
# Out:
# Wear sunglasses!

# %%
# more than one condition

x = 5
if x < 0:
  print("negative")
elif x == 0:
  print("null")
else: # my_variable > 0
  print("positive")

# %%
# @title ☁️Exercise:
print('Using the average temperature from the previous exercise, print a message saying whether the weather is "hot" or "cool".')

# %% [markdown]
# # 7. Loop:
# * Definition: A loop is a structure that allows you to repeat a block of code multiple times, based on a condition or a set of items.
# * Types:
# 1. For Loop: Repeats a block of code a fixed number of times.
#
# ![98a45435-23d3-42c3-b743-70c897c0e5c1_edited_for_loop_syntax.png](data:image/png;base64,...)

# %%
for i in range(5):
    print(i)  # Prints 0, 1, 2, 3, 4
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 2. While Loop: Repeats a block of code as long as a condition is true.
#
# ![while-anatomy.png](data:image/png;base64,...)

# %%
while x < 10:
    x += 1  # Increases x by 1 until it reaches 10, equivalent to x = x + 1

# %% [markdown]
# If the goal is simply to iterate over a list, we can do so directly as follows

# %%
grades = [89,62, 99, 85, 97, 65, 54]

# %%
for grade in grades:
  print(grade)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### 7.1 Combining Conditionals and Loops

# %%
for grade in grades:
  if grade < 70:
    print("Pass",grade)

# %% [markdown]
# ### 7.2 Loop Control Statements:
# * Definition: Special statements that control how a loop operates.
# Break: Exits the loop.
# * Continue: Skips the rest of the current loop iteration.
# Example:

# %%
for i in range(5):
    if i == 3:
        break  # Stops the loop when i is 3
    print(i)  # Outputs: 0, 1, 2
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 3:
        continue  # continue the loop when i is 3 (skip when i is 3)
    print(i)  # Outputs: 0, 1, 2
# Out:
# 0
# 1
# 2
# 4

# %%
# @title 🚀Exercise:
print('Use a for loop to print all the countries in the list of countries for space exploration from earlier.')
# Out:
# Use a for loop to print all the countries in the list of countries for space exploration from earlier.

# %%
# @title 🚀Exercise:
print('Loop through the list of countries for space exploration. For each country, \nprint if they have a space agency (you can assume USA, Russia, and China have one).')
# Out:
# Loop through the list of countries for space exploration. For each country,
# print if they have a space agency (you can assume USA, Russia, and China have one).

# %% [markdown]
# # 8. Functions and Return Statement:
# ## Function:
# * Definition: A function is a block of reusable code that performs a specific task. It takes input (optional),
# processes it, and returns an output (optional).
#
# ## Return Statement:
# * Definition: Used in a function to send the result back to the caller.
#
# ![Function_anatomy.png](data:image/png;base64,...)
#
# * Example:

# %%
def add(a, b):
    return a + b  # Adds two numbers and returns the result

print(add(3, 4))  # Outputs: 7
# Out:
# 7

# %%
def square(x):
  return x ** 2

print(square(4))  # Outputs: 16
# Out:
# 16

# %%
def multiply(a, b):
  return a * b

# Functions can be composed.
square(multiply(3, 2))
# Out:
# 36

# %% [markdown]
# To improve code readability, it is sometimes useful to explicitly name the arguments

# %%
square(multiply(a=3, b=2))
# Out:
# 36

# %%
# @title 🏋️‍♀️Exercise:
print('Write a function calculate_bmi(weight, height) that calculates and returns the BMI (Body Mass Index). \nUse it to calculate the BMI of a person who weighs 70 kg and has a height of 1.75 meters.')
# Out:
# Write a function calculate_bmi(weight, height) that calculates and returns the BMI (Body Mass Index).
# Use it to calculate the BMI of a person who weighs 70 kg and has a height of 1.75 meters.

# %% [markdown]
# BMI formula:
# ![Screenshot 2025-02-04 035901.png](data:image/png;base64,...)

# %% [markdown]
# # 9. Input/Output (I/O):
# * Definition:
# * Input: How a program receives data from a user.
#
# * Output: How a program displays data to the user.
# * Example:

# %%
name = input("Enter your name: ")  # Input
print("Hello, " + name)  # Output
# Out:
# Enter your name: Adam
# Hello, Adam

# %%
# @title 🏋️‍♀️Exercise:
print('Prompt the user to input their weight (in kg) and height (in meters), \nthen calculate and print their BMI using the function from the previous exercise.')
# Out:
# Prompt the user to input their weight (in kg) and height (in meters),
# then calculate and print their BMI using the function from the previous exercise.

# %% [markdown]
#  # **10. Applied Project!** 💯
#
# Your mission is create a "**Student Grading System**" where users can input student names and their grades, calculate average scores, and determine if the student passed or failed based on a set passing score.
#
# 📚 **Student Grading System Features:**
# * User Input: Enter student names and their grades.
# * Grade Calculation: The program will calculate the average grade.
# * Pass or Fail Judgment: The program will determine if the student passes or fails based on a passing grade threshold (e.g., 50%)."

# %%
# Function to calculate average grade
def calculate_average(grades):
    return ... #TODO

# Function to determine if the student passed or failed
def check_pass_fail(average_grade, passing_grade=50):
    if ...:#TODO
        return "Pass"
    else:
        return "Fail"

# Main program
def grading_system():
    print("Welcome to the Student Grading System")

    # Initialize an empty list to store student data
    students = ... #TODO

    # Get the number of students
    num_students = ... #TODO Note: the input should be int and the prompt is"How many students do you want to enter?"

    # Loop to input data for each student
    for _ in range(...): # TODO
        name = input("Enter the student's name: ")
        grades_input = input("Enter the student's grades separated by spaces: ").split()

        # Convert grades to integers
        grades = [int(grade) for grade in grades_input]

        # Calculate average grade
        average = ... #TODO

        # Check if the student passed or failed
        result = ... #TODO

        # Store student data (name, average grade, result)
        students.append((name, average, result))

    # Display the results
    print("\nStudent Results:")
    for student in students:
        name, average, result = student
        print(f"Name: {name}, Average Grade: {average:.2f}, Result: {result}")

# Run the program
grading_system()
